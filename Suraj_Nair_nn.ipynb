# %% [markdown]
# # **Melanoma Detection Assignment**

# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ## Importing the Libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# defining path from Google drive

data_dir_train = pathlib.Path("/content/gdrive/MyDrive/Melanoma Detection Assignment/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path("/content/gdrive/MyDrive/Melanoma Detection Assignment/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test")

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ## Creating dataset
#
# ## Loading using keras.preprocessing

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split = 0.2,
    subset='training',
    image_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split = 0.2,
    subset='validation',
    image_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualizing the data
#
# Creating a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# The image_batch contains 32 images, each 180 pixels wide and tall with 3 color channels (RGB). The label_batch has 32 corresponding labels for these images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## Creating the model
# Building a CNN model to classify images into 9 categories. Normalize pixel values from 0-255 to 0-1 using layers.experimental.preprocessing.Rescaling for optimal neural network performance.

# %%
# Number of target labels are 9
target_labels = 9

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)), # Rescaling is now directly under layers
  layers.Conv2D(16, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Conv2D(32, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Conv2D(64, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation=tf.nn.relu),
  layers.Dense(target_labels)
])

# %% [markdown]
# ## Compiling the data

# %%
# Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling_1 (Rescaling)              │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 180, 180, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 90, 90, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 90, 90, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 45, 45, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 45, 45, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 30976)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │       3,965,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 9)                   │           1,161 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,989,801 (15.22 MB)
#  Trainable params: 3,989,801 (15.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Training the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 707s 3s/step - accuracy: 0.2653 - loss: 2.0035 - val_accuracy: 0.4385 - val_loss: 1.6770
# Epoch 2/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.4326 - loss: 1.5855 - val_accuracy: 0.5056 - val_loss: 1.5198
# Epoch 3/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5018 - loss: 1.4717 - val_accuracy: 0.4944 - val_loss: 1.4492
# Epoch 4/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5378 - loss: 1.3342 - val_accuracy: 0.5280 - val_loss: 1.3584
# Epoch 5/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5715 - loss: 1.2319 - val_accuracy: 0.5526 - val_loss: 1.3460
# Epoch 6/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5814 - loss: 1.1642 - val_accuracy: 0.5727 - val_loss: 1.3434
# Epoch 7/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6797 - loss: 0.9481 - val_accuracy: 0.5391 - val_loss: 1.3412
# Epoch 8/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6756 - loss: 0.9479 - val_accuracy: 0.5414 - val_loss: 1.4407
# Epoch 9/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7093 - loss: 0.8099 - val_accuracy: 0.5481 - val_loss: 1.4256
# Epoch 10/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7245 - loss: 0.7506 - val_accuracy: 0.5638 - val_loss: 1.5120
# Epoch 11/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7747 - loss: 0.6222 - val_accuracy: 0.5481 - val_loss: 1.5177
# Epoch 12/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8071 - loss: 0.5688 - val_accuracy: 0.5257 - val_loss: 1.9356
# Epoch 13/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8259 - loss: 0.5028 - val_accuracy: 0.5391 - val_loss: 1.8512
# Epoch 14/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8658 - loss: 0.3655 - val_accuracy: 0.5503 - val_loss: 1.9976
# Epoch 15/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8524 - loss: 0.4126 - val_accuracy: 0.5056 - val_loss: 2.1472
# Epoch 16/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8726 - loss: 0.3573 - val_accuracy: 0.5660 - val_loss: 1.9612
# Epoch 17/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8940 - loss: 0.2661 - val_accuracy: 0.5705 - val_loss: 2.1932
# Epoch 18/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9080 - loss: 0.2323 - val_accuracy: 0.5414 - val_loss: 2.2075
# Epoch 19/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9268 - loss: 0.1969 - val_accuracy: 0.5638 - val_loss: 2.3377
# Epoch 20/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9137 - loss: 0.2146 - val_accuracy: 0.5615 - val_loss: 2.3200

# %% [markdown]
# ## Visualizing the data

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# 1. The model's training accuracy improves significantly to 90%, but validation accuracy stays at 55%.
# 2. High training accuracy, low validation accuracy suggests the model is overfitting, learning noise instead of general patterns.
# 3. To combat overfitting, we'll use data augmentation. By creating new, slightly modified training images, we'll improve the model's ability to generalize to unseen data.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Choosing an appropriate data augumentation strategy.
augmentation_data = keras.Sequential([
                                      layers.RandomFlip("horizontal", input_shape=(img_height, img_width, 3)),
                                      layers.RandomRotation(0.1),
                                      layers.RandomZoom(0.1),
])

# %%
# Visualizing augmentation startegy

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        augmented_images = augmentation_data(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.title(class_names[labels[0]])
        plt.axis("off")

# %% [markdown]
# # Creating, Compiling and Training the model

# %%
import tensorflow as tf
from tensorflow.keras.layers import Rescaling

#Create
model = Sequential([
  augmentation_data,
  Rescaling(1./255),
  layers.Conv2D(16, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Conv2D(32, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Conv2D(64, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation=tf.nn.relu),
  layers.Dense(target_labels)
])

# %%
# Compile

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# Training the model

history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - accuracy: 0.1885 - loss: 2.3015 - val_accuracy: 0.2528 - val_loss: 1.9582
# Epoch 2/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.3002 - loss: 1.8714 - val_accuracy: 0.3960 - val_loss: 1.7006
# Epoch 3/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.4312 - loss: 1.6198 - val_accuracy: 0.4877 - val_loss: 1.4927
# Epoch 4/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.4719 - loss: 1.4492 - val_accuracy: 0.5056 - val_loss: 1.4848
# Epoch 5/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.4355 - loss: 1.5056 - val_accuracy: 0.4743 - val_loss: 1.5337
# Epoch 6/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5002 - loss: 1.4315 - val_accuracy: 0.5280 - val_loss: 1.3681
# Epoch 7/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.5257 - loss: 1.3674 - val_accuracy: 0.5123 - val_loss: 1.4020
# Epoch 8/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.5002 - loss: 1.3728 - val_accuracy: 0.5101 - val_loss: 1.4605
# Epoch 9/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.5234 - loss: 1.3444 - val_accuracy: 0.5414 - val_loss: 1.3513
# Epoch 10/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.5433 - loss: 1.2727 - val_accuracy: 0.5056 - val_loss: 1.4206
# Epoch 11/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.5601 - loss: 1.2239 - val_accuracy: 0.5190 - val_loss: 1.3569
# Epoch 12/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.5414 - loss: 1.2421 - val_accuracy: 0.5190 - val_loss: 1.3538
# Epoch 13/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.5606 - loss: 1.2336 - val_accuracy: 0.5324 - val_loss: 1.4081
# Epoch 14/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5449 - loss: 1.2305 - val_accuracy: 0.5503 - val_loss: 1.2991
# Epoch 15/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.5910 - loss: 1.1424 - val_accuracy: 0.5101 - val_loss: 1.4353
# Epoch 16/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6040 - loss: 1.1458 - val_accuracy: 0.5436 - val_loss: 1.3068
# Epoch 17/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.5940 - loss: 1.1503 - val_accuracy: 0.5324 - val_loss: 1.3614
# Epoch 18/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.5852 - loss: 1.1251 - val_accuracy: 0.5481 - val_loss: 1.3170
# Epoch 19/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.6143 - loss: 1.0568 - val_accuracy: 0.5257 - val_loss: 1.3504
# Epoch 20/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.6372 - loss: 1.0134 - val_accuracy: 0.5503 - val_loss: 1.3315

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# 1. Data augmentation has mitigated overfitting.
# 2. The model's training and validation accuracy are now comparable.
# 3. Both training and validation accuracy are low, suggesting underfitting.

# %% [markdown]
# ## Finding the distribution of classes in the training dataset.

# %%
## Your code goes here.

from glob import glob

## find the image path for all class labels (lesions)
images_path_list = [ i for i in glob(os.path.join(data_dir_train, '*', '*.jpg')) ]

## Extract the class labels (lesions)
lesions_list = [ os.path.basename(os.path.dirname(j)) for j in glob(os.path.join(data_dir_train, '*', '*.jpg')) ]
print(len(lesions_list))
# Out:
# 2239

# %%
# Extracting image path and class label in a dictionary

image_dict = dict(zip(images_path_list, lesions_list))
print(list(image_dict.items())[:5])
# Out:
# [('/content/gdrive/MyDrive/Melanoma Detection Assignment/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0025924.jpg', 'vascular lesion'), ('/content/gdrive/MyDrive/Melanoma Detection Assignment/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0026068.jpg', 'vascular lesion'), ('/content/gdrive/MyDrive/Melanoma Detection Assignment/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0024867.jpg', 'vascular lesion'), ('/content/gdrive/MyDrive/Melanoma Detection Assignment/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0025244.jpg', 'vascular lesion'), ('/content/gdrive/MyDrive/Melanoma Detection Assignment/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0024904.jpg', 'vascular lesion')]

# %%
# Viewing the image path and class label in a df
lesions_df = pd.DataFrame(list(image_dict.items()), columns=['Image Path', 'Label'])
lesions_df.head()
# Out:
#                                           Image Path            Label
# 0  /content/gdrive/MyDrive/Melanoma Detection Ass...  vascular lesion
# 1  /content/gdrive/MyDrive/Melanoma Detection Ass...  vascular lesion
# 2  /content/gdrive/MyDrive/Melanoma Detection Ass...  vascular lesion
# 3  /content/gdrive/MyDrive/Melanoma Detection Ass...  vascular lesion
# 4  /content/gdrive/MyDrive/Melanoma Detection Ass...  vascular lesion

# %%
## Inspecting the distribution of classes in the data
lesions_df[['Label']].value_counts()
# Out:
# Label
# pigmented benign keratosis    462
# melanoma                      438
# basal cell carcinoma          376
# nevus                         357
# squamous cell carcinoma       181
# vascular lesion               139
# actinic keratosis             114
# dermatofibroma                 95
# seborrheic keratosis           77
# Name: count, dtype: int64

# %%
import seaborn as sns

plt.figure(figsize=(10, 10))
sns.countplot(y="Label", data=lesions_df)
plt.title('No. of images belonging to a Type v/s Types of Skin Lesion', fontsize=16)
plt.xlabel('No. of images in a particular skin lesion type', fontsize=14)
plt.ylabel('Skin Lesion Types', fontsize=14)
plt.show()

# %% [markdown]
# **Findings**
#
# Which class has the least number of samples?
#
# Ans.seborrheic keratosis (77)
#
# Which classes dominate the data in terms proportionate number of samples?
#
# Ans pigmented benign keratosis (462)

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (11.0.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.66.6)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.26.4)
# Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# ## Rectify the class imbalance using augmentor

# %%
## We are adding 500 samples per class to make sure that none of the classes are sparse.

path_to_training_dataset = str(data_dir_train) + '/'

import Augmentor

for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500)
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Melanoma Detection Assignment/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7ABE496F03D0>: 100%|██████████| 500/500 [00:19<00:00, 26.14 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Melanoma Detection Assignment/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7ABDEE51EEC0>: 100%|██████████| 500/500 [00:19<00:00, 25.50 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Melanoma Detection Assignment/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7ABE26221DE0>: 100%|██████████| 500/500 [00:19<00:00, 25.05 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Melanoma Detection Assignment/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=3072x2304 at 0x7ABDEE51EF50>: 100%|██████████| 500/500 [01:40<00:00,  4.98 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Melanoma Detection Assignment/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=3072x2304 at 0x7ABDAC75CDF0>: 100%|██████████| 500/500 [01:21<00:00,  6.10 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Melanoma Detection Assignment/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7ABE203833D0>: 100%|██████████| 500/500 [00:22<00:00, 22.64 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Melanoma Detection Assignment/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x7ABE2644D600>: 100%|██████████| 500/500 [00:43<00:00, 11.50 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Melanoma Detection Assignment/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7ABDBA0C6620>: 100%|██████████| 500/500 [00:20<00:00, 24.83 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Melanoma Detection Assignment/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7ABE49872D70>: 100%|██████████| 500/500 [00:22<00:00, 21.94 Samples/s]

# %% [markdown]
# Lets take a look at total count of augmented images.

# %%
# Verifying the total count of images after the augmentation
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %%
# extracting the augmented image paths in a list
path_list_new = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list_new[:5]
# Out:
# ['/content/gdrive/MyDrive/Melanoma Detection Assignment/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output/vascular lesion_original_ISIC_0032538.jpg_c9f18432-2c1b-47d5-9f68-985139db9101.jpg',
#  '/content/gdrive/MyDrive/Melanoma Detection Assignment/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output/vascular lesion_original_ISIC_0025244.jpg_c17a49b7-72ce-46fc-ae57-44b2308a6ea3.jpg',
#  '/content/gdrive/MyDrive/Melanoma Detection Assignment/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output/vascular lesion_original_ISIC_0024669.jpg_f1afdf9a-815e-4d0f-9fb6-a65c40dda7b6.jpg',
#  '/content/gdrive/MyDrive/Melanoma Detection Assignment/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output/vascular lesion_original_ISIC_0033591.jpg_70f11df2-26e3-4863-8b9d-ad7c45d80051.jpg',
#  '/content/gdrive/MyDrive/Melanoma Detection Assignment/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output/vascular lesion_original_ISIC_0033092.jpg_f3fef3db-c69c-42ec-83ae-74177df512c4.jpg']

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new[:5]
# Out:
# ['vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion']

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Image Path','Label'])
new_df = pd.concat([lesions_df, df2], ignore_index=True)
new_df.shape
# Out:
# (6739, 2)

# %%
new_df.head()
# Out:
#                                           Image Path            Label
# 0  /content/gdrive/MyDrive/Melanoma Detection Ass...  vascular lesion
# 1  /content/gdrive/MyDrive/Melanoma Detection Ass...  vascular lesion
# 2  /content/gdrive/MyDrive/Melanoma Detection Ass...  vascular lesion
# 3  /content/gdrive/MyDrive/Melanoma Detection Ass...  vascular lesion
# 4  /content/gdrive/MyDrive/Melanoma Detection Ass...  vascular lesion

# %%
new_df['Label'].value_counts()
# Out:
# Label
# pigmented benign keratosis    962
# melanoma                      938
# basal cell carcinoma          876
# nevus                         857
# squamous cell carcinoma       681
# vascular lesion               639
# actinic keratosis             614
# dermatofibroma                595
# seborrheic keratosis          577
# Name: count, dtype: int64

# %% [markdown]
# We've balanced the dataset by adding 500 images to each class. We can further improve training by adding more images.

# %% [markdown]
# ## Now using the augmented data to train the model.

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# ### Creating training data

# %%
# data_dir_train="path to directory with training data + data created using augmentor"

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# ### Creating validate dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# ### Creating the model with normalization

# %%
model = Sequential([
  augmentation_data,
  Rescaling(1./255),
  layers.Conv2D(16, (3, 3), padding='same', activation=tf.nn.relu),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Conv2D(32, (3, 3), padding='same', activation=tf.nn.relu),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Conv2D(64, (3, 3), padding='same', activation=tf.nn.relu),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation=tf.nn.relu),
  layers.Dense(target_labels)
])

# %% [markdown]
# ### Compiling the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 51s 278ms/step - accuracy: 0.2249 - loss: 3.3653 - val_accuracy: 0.1062 - val_loss: 10.9873
# Epoch 2/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 45s 264ms/step - accuracy: 0.2707 - loss: 1.8643 - val_accuracy: 0.1203 - val_loss: 16.0755
# Epoch 3/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 79s 249ms/step - accuracy: 0.2939 - loss: 1.7902 - val_accuracy: 0.2249 - val_loss: 2.2316
# Epoch 4/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 85s 268ms/step - accuracy: 0.3334 - loss: 1.6905 - val_accuracy: 0.2658 - val_loss: 1.9348
# Epoch 5/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 246ms/step - accuracy: 0.3390 - loss: 1.6713 - val_accuracy: 0.3563 - val_loss: 1.7941
# Epoch 6/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 84s 257ms/step - accuracy: 0.3923 - loss: 1.5937 - val_accuracy: 0.3690 - val_loss: 1.7991
# Epoch 7/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 84s 271ms/step - accuracy: 0.4091 - loss: 1.5630 - val_accuracy: 0.4105 - val_loss: 1.6038
# Epoch 8/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 79s 251ms/step - accuracy: 0.4366 - loss: 1.5226 - val_accuracy: 0.4581 - val_loss: 1.5300
# Epoch 9/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 83s 261ms/step - accuracy: 0.4602 - loss: 1.4445 - val_accuracy: 0.3846 - val_loss: 1.5506
# Epoch 10/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 246ms/step - accuracy: 0.4744 - loss: 1.3692 - val_accuracy: 0.4714 - val_loss: 1.3930
# Epoch 11/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 83s 253ms/step - accuracy: 0.4811 - loss: 1.3893 - val_accuracy: 0.4907 - val_loss: 1.3252
# Epoch 12/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 43s 253ms/step - accuracy: 0.4725 - loss: 1.3336 - val_accuracy: 0.4729 - val_loss: 1.3424
# Epoch 13/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 81s 246ms/step - accuracy: 0.4911 - loss: 1.2736 - val_accuracy: 0.4157 - val_loss: 1.6155
# Epoch 14/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 83s 256ms/step - accuracy: 0.4893 - loss: 1.2825 - val_accuracy: 0.5056 - val_loss: 1.2266
# Epoch 15/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 83s 261ms/step - accuracy: 0.5152 - loss: 1.2347 - val_accuracy: 0.4618 - val_loss: 1.4375
# Epoch 16/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 83s 266ms/step - accuracy: 0.5070 - loss: 1.2677 - val_accuracy: 0.4736 - val_loss: 1.3340
# Epoch 17/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 81s 261ms/step - accuracy: 0.5087 - loss: 1.2411 - val_accuracy: 0.4566 - val_loss: 1.5613
# Epoch 18/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 79s 243ms/step - accuracy: 0.5193 - loss: 1.2082 - val_accuracy: 0.5108 - val_loss: 1.2735
# Epoch 19/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 84s 254ms/step - accuracy: 0.5226 - loss: 1.1776 - val_accuracy: 0.4699 - val_loss: 1.3391
# Epoch 20/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 83s 259ms/step - accuracy: 0.5289 - loss: 1.1637 - val_accuracy: 0.4974 - val_loss: 1.2815

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# Observations
#
# 1. Adding batch normalization slightly improved both training and validation accuracy.
# 2. We will now create a model without batch normalization to see if accuracy can be further improved.

# %% [markdown]
# ## Creating another model without batch normalization

# %%
model = Sequential([
  augmentation_data,
  Rescaling(1./255),
  layers.Conv2D(16, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Conv2D(32, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Conv2D(64, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation=tf.nn.relu),
  layers.Dense(target_labels)
])

# %% [markdown]
# ### Compiling the model

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

checkpoint = ModelCheckpoint("model.keras", monitor="val_accuracy", save_best_only=True, mode="auto", verbose=1)

earlystop = EarlyStopping(monitor="val_accuracy", patience=5, mode="auto", verbose=1)

# %% [markdown]
# ### Training the model

# %%
epochs = 50
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[checkpoint, earlystop]
)
# Out:
# Epoch 1/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.2302 - loss: 2.0687
# Epoch 1: val_accuracy improved from -inf to 0.40535, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 241ms/step - accuracy: 0.2304 - loss: 2.0676 - val_accuracy: 0.4053 - val_loss: 1.6183
# Epoch 2/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.3906 - loss: 1.5753
# Epoch 2: val_accuracy did not improve from 0.40535
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 40s 239ms/step - accuracy: 0.3907 - loss: 1.5752 - val_accuracy: 0.3846 - val_loss: 1.6199
# Epoch 3/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.4389 - loss: 1.4695
# Epoch 3: val_accuracy improved from 0.40535 to 0.44915, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 40s 231ms/step - accuracy: 0.4389 - loss: 1.4694 - val_accuracy: 0.4491 - val_loss: 1.4374
# Epoch 4/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.4803 - loss: 1.3798
# Epoch 4: val_accuracy improved from 0.44915 to 0.48033, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 235ms/step - accuracy: 0.4803 - loss: 1.3797 - val_accuracy: 0.4803 - val_loss: 1.3091
# Epoch 5/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.5168 - loss: 1.2754
# Epoch 5: val_accuracy improved from 0.48033 to 0.49369, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 234ms/step - accuracy: 0.5168 - loss: 1.2755 - val_accuracy: 0.4937 - val_loss: 1.3251
# Epoch 6/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.5205 - loss: 1.2384
# Epoch 6: val_accuracy did not improve from 0.49369
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 43s 254ms/step - accuracy: 0.5206 - loss: 1.2383 - val_accuracy: 0.4759 - val_loss: 1.3254
# Epoch 7/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.5226 - loss: 1.2493
# Epoch 7: val_accuracy improved from 0.49369 to 0.55754, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 82s 257ms/step - accuracy: 0.5227 - loss: 1.2491 - val_accuracy: 0.5575 - val_loss: 1.1368
# Epoch 8/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.5582 - loss: 1.1545
# Epoch 8: val_accuracy improved from 0.55754 to 0.57684, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 80s 244ms/step - accuracy: 0.5581 - loss: 1.1545 - val_accuracy: 0.5768 - val_loss: 1.1235
# Epoch 9/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.5835 - loss: 1.1002
# Epoch 9: val_accuracy did not improve from 0.57684
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 81s 238ms/step - accuracy: 0.5834 - loss: 1.1005 - val_accuracy: 0.5531 - val_loss: 1.1946
# Epoch 10/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.5859 - loss: 1.0814
# Epoch 10: val_accuracy improved from 0.57684 to 0.60431, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 240ms/step - accuracy: 0.5859 - loss: 1.0814 - val_accuracy: 0.6043 - val_loss: 1.0678
# Epoch 11/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.5904 - loss: 1.0677
# Epoch 11: val_accuracy improved from 0.60431 to 0.61247, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 241ms/step - accuracy: 0.5905 - loss: 1.0676 - val_accuracy: 0.6125 - val_loss: 1.0456
# Epoch 12/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.6291 - loss: 0.9722
# Epoch 12: val_accuracy did not improve from 0.61247
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 238ms/step - accuracy: 0.6291 - loss: 0.9723 - val_accuracy: 0.5976 - val_loss: 1.0706
# Epoch 13/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.6253 - loss: 0.9778
# Epoch 13: val_accuracy did not improve from 0.61247
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 241ms/step - accuracy: 0.6253 - loss: 0.9777 - val_accuracy: 0.6058 - val_loss: 1.0612
# Epoch 14/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.6239 - loss: 0.9529
# Epoch 14: val_accuracy improved from 0.61247 to 0.63400, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 241ms/step - accuracy: 0.6239 - loss: 0.9528 - val_accuracy: 0.6340 - val_loss: 0.9579
# Epoch 15/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.6566 - loss: 0.8963
# Epoch 15: val_accuracy improved from 0.63400 to 0.66667, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 240ms/step - accuracy: 0.6566 - loss: 0.8963 - val_accuracy: 0.6667 - val_loss: 0.9026
# Epoch 16/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.6608 - loss: 0.8829
# Epoch 16: val_accuracy improved from 0.66667 to 0.68077, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 40s 233ms/step - accuracy: 0.6608 - loss: 0.8830 - val_accuracy: 0.6808 - val_loss: 0.8561
# Epoch 17/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.6829 - loss: 0.8379
# Epoch 17: val_accuracy did not improve from 0.68077
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 44s 249ms/step - accuracy: 0.6829 - loss: 0.8380 - val_accuracy: 0.6377 - val_loss: 0.9712
# Epoch 18/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.6717 - loss: 0.8542
# Epoch 18: val_accuracy improved from 0.68077 to 0.69859, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 80s 239ms/step - accuracy: 0.6717 - loss: 0.8541 - val_accuracy: 0.6986 - val_loss: 0.8199
# Epoch 19/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.7090 - loss: 0.7725
# Epoch 19: val_accuracy improved from 0.69859 to 0.70973, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 250ms/step - accuracy: 0.7090 - loss: 0.7725 - val_accuracy: 0.7097 - val_loss: 0.7779
# Epoch 20/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.7193 - loss: 0.7431
# Epoch 20: val_accuracy improved from 0.70973 to 0.72309, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 79s 235ms/step - accuracy: 0.7193 - loss: 0.7432 - val_accuracy: 0.7231 - val_loss: 0.7792
# Epoch 21/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.7183 - loss: 0.7318
# Epoch 21: val_accuracy did not improve from 0.72309
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 238ms/step - accuracy: 0.7183 - loss: 0.7318 - val_accuracy: 0.6763 - val_loss: 0.8840
# Epoch 22/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.7188 - loss: 0.7477
# Epoch 22: val_accuracy improved from 0.72309 to 0.74313, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 43s 248ms/step - accuracy: 0.7188 - loss: 0.7477 - val_accuracy: 0.7431 - val_loss: 0.7231
# Epoch 23/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.7248 - loss: 0.7316
# Epoch 23: val_accuracy did not improve from 0.74313
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 80s 236ms/step - accuracy: 0.7247 - loss: 0.7317 - val_accuracy: 0.7238 - val_loss: 0.7535
# Epoch 24/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.7444 - loss: 0.6804
# Epoch 24: val_accuracy did not improve from 0.74313
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 239ms/step - accuracy: 0.7444 - loss: 0.6804 - val_accuracy: 0.7186 - val_loss: 0.7821
# Epoch 25/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.7462 - loss: 0.6735
# Epoch 25: val_accuracy improved from 0.74313 to 0.74981, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 44s 258ms/step - accuracy: 0.7462 - loss: 0.6735 - val_accuracy: 0.7498 - val_loss: 0.6877
# Epoch 26/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.7652 - loss: 0.6467
# Epoch 26: val_accuracy did not improve from 0.74981
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 77s 228ms/step - accuracy: 0.7651 - loss: 0.6468 - val_accuracy: 0.7194 - val_loss: 0.7476
# Epoch 27/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.7596 - loss: 0.6174
# Epoch 27: val_accuracy improved from 0.74981 to 0.76095, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 43s 238ms/step - accuracy: 0.7596 - loss: 0.6174 - val_accuracy: 0.7610 - val_loss: 0.6667
# Epoch 28/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.7627 - loss: 0.6191
# Epoch 28: val_accuracy did not improve from 0.76095
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 249ms/step - accuracy: 0.7627 - loss: 0.6192 - val_accuracy: 0.6845 - val_loss: 0.9142
# Epoch 29/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.7642 - loss: 0.6207
# Epoch 29: val_accuracy did not improve from 0.76095
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 82s 248ms/step - accuracy: 0.7642 - loss: 0.6206 - val_accuracy: 0.7506 - val_loss: 0.7261
# Epoch 30/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.7560 - loss: 0.6302
# Epoch 30: val_accuracy improved from 0.76095 to 0.77431, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 80s 237ms/step - accuracy: 0.7561 - loss: 0.6301 - val_accuracy: 0.7743 - val_loss: 0.7019
# Epoch 31/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.7757 - loss: 0.5867
# Epoch 31: val_accuracy did not improve from 0.77431
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 238ms/step - accuracy: 0.7757 - loss: 0.5867 - val_accuracy: 0.7120 - val_loss: 0.9217
# Epoch 32/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.7526 - loss: 0.6831
# Epoch 32: val_accuracy improved from 0.77431 to 0.77877, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 44s 255ms/step - accuracy: 0.7528 - loss: 0.6826 - val_accuracy: 0.7788 - val_loss: 0.6421
# Epoch 33/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.7963 - loss: 0.5223
# Epoch 33: val_accuracy did not improve from 0.77877
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 78s 232ms/step - accuracy: 0.7963 - loss: 0.5223 - val_accuracy: 0.7253 - val_loss: 0.7943
# Epoch 34/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.7976 - loss: 0.5292
# Epoch 34: val_accuracy improved from 0.77877 to 0.78693, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 242ms/step - accuracy: 0.7976 - loss: 0.5292 - val_accuracy: 0.7869 - val_loss: 0.6437
# Epoch 35/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.7935 - loss: 0.5347
# Epoch 35: val_accuracy improved from 0.78693 to 0.79659, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 40s 239ms/step - accuracy: 0.7936 - loss: 0.5347 - val_accuracy: 0.7966 - val_loss: 0.5909
# Epoch 36/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.7980 - loss: 0.5068
# Epoch 36: val_accuracy did not improve from 0.79659
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 239ms/step - accuracy: 0.7980 - loss: 0.5069 - val_accuracy: 0.7387 - val_loss: 0.7322
# Epoch 37/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.8068 - loss: 0.5004
# Epoch 37: val_accuracy did not improve from 0.79659
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 43s 251ms/step - accuracy: 0.8069 - loss: 0.5003 - val_accuracy: 0.7929 - val_loss: 0.6299
# Epoch 38/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.8086 - loss: 0.5048
# Epoch 38: val_accuracy did not improve from 0.79659
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 79s 231ms/step - accuracy: 0.8086 - loss: 0.5049 - val_accuracy: 0.7951 - val_loss: 0.5549
# Epoch 39/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.7953 - loss: 0.5325
# Epoch 39: val_accuracy did not improve from 0.79659
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 233ms/step - accuracy: 0.7954 - loss: 0.5324 - val_accuracy: 0.7914 - val_loss: 0.6425
# Epoch 40/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.8328 - loss: 0.4561
# Epoch 40: val_accuracy did not improve from 0.79659
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 235ms/step - accuracy: 0.8328 - loss: 0.4561 - val_accuracy: 0.7906 - val_loss: 0.6033
# Epoch 40: early stopping

# %% [markdown]
# ### Visualizing the result

# %%
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential_2 (Sequential)            │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling_4 (Rescaling)              │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_12 (Conv2D)                   │ (None, 180, 180, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_12 (MaxPooling2D)      │ (None, 90, 90, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_13 (Conv2D)                   │ (None, 90, 90, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_13 (MaxPooling2D)      │ (None, 45, 45, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_14 (Conv2D)                   │ (None, 45, 45, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_14 (MaxPooling2D)      │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_4 (Flatten)                  │ (None, 30976)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 128)                 │       3,965,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 9)                   │           1,161 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 11,969,405 (45.66 MB)
#  Trainable params: 3,989,801 (15.22 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 7,979,604 (30.44 MB)

# %%
# Ploting the training curves

epochs_range = range(earlystop.stopped_epoch+1)

plt.figure(figsize=(15, 10))
plt.subplot(1, 2, 1)

#Ploting Model Accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel(epochs_range)
plt.legend(['train', 'val'], loc='upper left')

#Ploting Model Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel(epochs_range)
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# 1. The model demonstrates optimal performance, avoiding both underfitting and overfitting.
# 2. Class rebalancing significantly improved the model's performance on both training and validation data.
# 3. The minimal difference between training and validation accuracies indicates the strong generalization ability of the final CNN model.
# 4. The inclusion of batch normalization did not lead to improved performance on either training or validation data.

# %% [markdown]
# ## Model Evaluation

# %%
from tensorflow.keras.preprocessing.image import load_img

image_path_test = os.path.join(data_dir_test, class_names[1], '*')
test_image = glob(image_path_test)
test_image = load_img(test_image[-1], target_size=(180, 180, 3))
plt.imshow(test_image)
plt.grid(False)

img = np.expand_dims(test_image, axis=0)
predicted = model.predict(img)
predicted = np.argmax(predicted)
predicted_class = class_names[predicted]
print("Actual Class: " + class_names[1] +'\n'+ "Predicted Class: " + predicted_class)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# Actual Class: basal cell carcinoma
# Predicted Class: basal cell carcinoma
